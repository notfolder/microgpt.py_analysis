# %% [markdown]
# # V1: モデル構造可視化
#
# 学習済みmicroGPTモデルの構造とパラメータ統計を可視化し、モデルの全体像を把握します。

# %% [markdown]
# ## ライブラリのインポート

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from model_analyzer import ModelAnalyzer, InferenceEngine

# Seabornのスタイル設定
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

import japanize_matplotlib  # 日本語表示を有効化

# %% [markdown]
# ## ModelAnalyzerの初期化

# %%
# モデルの読み込み
analyzer = ModelAnalyzer('../model.json')
# Out:
# モデル読み込み完了: vocab_size=27, n_layer=1, n_embd=16, block_size=16, n_head=4

# %% [markdown]
# ## セクション1：モデル設定情報

# %%
# モデル設定の表示
print("=" * 50)
print("モデル設定情報")
print("=" * 50)
print(f"語彙サイズ (vocab_size):       {analyzer.vocab_size}")
print(f"レイヤー数 (n_layer):           {analyzer.n_layer}")
print(f"埋め込み次元 (n_embd):          {analyzer.n_embd}")
print(f"コンテキスト長 (block_size):    {analyzer.block_size}")
print(f"ヘッド数 (n_head):              {analyzer.n_head}")
print(f"ヘッド次元 (head_dim):          {analyzer.head_dim}")

# パラメータ統計を取得
stats = analyzer.get_parameter_stats()
print(f"総パラメータ数:                 {stats['total_params']:,}")
print("=" * 50)
# Out:
# ==================================================
# モデル設定情報
# ==================================================
# 語彙サイズ (vocab_size):       27
# レイヤー数 (n_layer):           1
# 埋め込み次元 (n_embd):          16
# コンテキスト長 (block_size):    16
# ヘッド数 (n_head):              4
# ヘッド次元 (head_dim):          4
# 総パラメータ数:                 4,192
# ==================================================

# %% [markdown]
# ## セクション2：レイヤー別パラメータ数

# %%
# レイヤー別パラメータ数のデータフレームを作成
params_data = []
for layer_name, count in stats['params_per_layer'].items():
    # レイヤーのタイプを判定
    if 'wte' in layer_name or 'wpe' in layer_name:
        layer_type = 'Embedding'
    elif 'attn' in layer_name:
        layer_type = 'Attention'
    elif 'mlp' in layer_name:
        layer_type = 'MLP'
    elif 'lm_head' in layer_name:
        layer_type = 'Output'
    else:
        layer_type = 'Other'
    
    params_data.append({
        'layer_name': layer_name,
        'param_count': count,
        'layer_type': layer_type
    })

params_df = pd.DataFrame(params_data)

# 棒グラフで可視化
plt.figure(figsize=(14, 6))
sns.barplot(data=params_df, x='layer_name', y='param_count', hue='layer_type', dodge=False)
plt.xticks(rotation=45, ha='right')
plt.yscale('log')
plt.ylabel('パラメータ数 (対数スケール)')
plt.xlabel('レイヤー名')
plt.title('レイヤー別パラメータ数')
plt.tight_layout()
plt.show()

print(f"\n全体の総パラメータ数: {stats['total_params']:,}")
# Out:
# 全体の総パラメータ数: 4,192

# %% [markdown]
# ## セクション3：重み行列の統計量

# %%
# 統計量のデータフレームを作成
stats_data = []
for layer_name, layer_stats in stats['stats_per_layer'].items():
    stats_data.append({
        '重み行列名': layer_name,
        '平均': layer_stats['mean'],
        '標準偏差': layer_stats['std'],
        '最小値': layer_stats['min'],
        '最大値': layer_stats['max']
    })

stats_df = pd.DataFrame(stats_data)

# DataFrameを表示（最大値を強調）
styled_df = stats_df.style.highlight_max(
    subset=['平均', '標準偏差', '最小値', '最大値'], 
    color='lightblue'
).format({
    '平均': '{:.6f}',
    '標準偏差': '{:.6f}',
    '最小値': '{:.6f}',
    '最大値': '{:.6f}'
})

display(styled_df)
# Out:
# <style type="text/css">
# #T_9d792_row2_col2, #T_9d792_row2_col4, #T_9d792_row6_col3, #T_9d792_row7_col1 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_9d792">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d792_level0_col0" class="col_heading level0 col0" >重み行列名</th>
#       <th id="T_9d792_level0_col1" class="col_heading level0 col1" >平均</th>
#       <th id="T_9d792_level0_col2" class="col_heading level0 col2" >標準偏差</th>
#       <th id="T_9d792_level0_col3" class="col_heading level0 col3" >最小値</th>
#       <th id="T_9d792_level0_col4" class="col_heading level0 col4" >最大値</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d792_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d792_row0_col0" class="data row0 col0" >wte</td>
#       <td id="T_9d792_row0_col1" class="data row0 col1" >0.002454</td>
#       <td id="T_9d792_row0_col2" class="data row0 col2" >0.199460</td>
#       <td id="T_9d792_row0_col3" class="data row0 col3" >-0.677077</td>
#       <td id="T_9d792_row0_col4" class="data row0 col4" >0.690343</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d792_row1_col0" class="data row1 col0" >wpe</td>
#       <td id="T_9d792_row1_col1" class="data row1 col1" >0.004882</td>
#       <td id="T_9d792_row1_col2" class="data row1 col2" >0.157416</td>
#       <td id="T_9d792_row1_col3" class="data row1 col3" >-0.725663</td>
#       <td id="T_9d792_row1_col4" class="data row1 col4" >0.427516</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d792_row2_col0" class="data row2 col0" >lm_head</td>
#       <td id="T_9d792_row2_col1" class="data row2 col1" >0.011964</td>
#       <td id="T_9d792_row2_col2" class="data row2 col2" >0.243929</td>
#       <td id="T_9d792_row2_col3" class="data row2 col3" >-0.756272</td>
#       <td id="T_9d792_row2_col4" class="data row2 col4" >1.332701</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d792_row3_col0" class="data row3 col0" >layer0.attn_wq</td>
#       <td id="T_9d792_row3_col1" class="data row3 col1" >0.003435</td>
#       <td id="T_9d792_row3_col2" class="data row3 col2" >0.157175</td>
#       <td id="T_9d792_row3_col3" class="data row3 col3" >-0.415313</td>
#       <td id="T_9d792_row3_col4" class="data row3 col4" >0.478714</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d792_row4_col0" class="data row4 col0" >layer0.attn_wk</td>
#       <td id="T_9d792_row4_col1" class="data row4 col1" >0.001488</td>
#       <td id="T_9d792_row4_col2" class="data row4 col2" >0.161582</td>
#       <td id="T_9d792_row4_col3" class="data row4 col3" >-0.550769</td>
#       <td id="T_9d792_row4_col4" class="data row4 col4" >0.471355</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d792_row5_col0" class="data row5 col0" >layer0.attn_wv</td>
#       <td id="T_9d792_row5_col1" class="data row5 col1" >0.003573</td>
#       <td id="T_9d792_row5_col2" class="data row5 col2" >0.123250</td>
#       <td id="T_9d792_row5_col3" class="data row5 col3" >-0.327808</td>
#       <td id="T_9d792_row5_col4" class="data row5 col4" >0.338300</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d792_row6_col0" class="data row6 col0" >layer0.attn_wo</td>
#       <td id="T_9d792_row6_col1" class="data row6 col1" >-0.023982</td>
#       <td id="T_9d792_row6_col2" class="data row6 col2" >0.109397</td>
#       <td id="T_9d792_row6_col3" class="data row6 col3" >-0.327706</td>
#       <td id="T_9d792_row6_col4" class="data row6 col4" >0.261390</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d792_row7_col0" class="data row7 col0" >layer0.mlp_fc1</td>
#       <td id="T_9d792_row7_col1" class="data row7 col1" >0.011972</td>
#       <td id="T_9d792_row7_col2" class="data row7 col2" >0.155643</td>
#       <td id="T_9d792_row7_col3" class="data row7 col3" >-0.641608</td>
#       <td id="T_9d792_row7_col4" class="data row7 col4" >0.526327</td>
#     </tr>
#     <tr>
#       <th id="T_9d792_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d792_row8_col0" class="data row8 col0" >layer0.mlp_fc2</td>
#       <td id="T_9d792_row8_col1" class="data row8 col1" >-0.005031</td>
#       <td id="T_9d792_row8_col2" class="data row8 col2" >0.125219</td>
#       <td id="T_9d792_row8_col3" class="data row8 col3" >-0.435907</td>
#       <td id="T_9d792_row8_col4" class="data row8 col4" >0.450149</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## セクション4：モデルアーキテクチャ図
#
# ```mermaid
# graph TD
#     A[入力トークン] --> B[Token Embedding]
#     A --> C[Position Embedding]
#     B --> D[埋め込みベクトル合成]
#     C --> D
#     D --> E[RMSNorm]
#     E --> F[Multi-Head Attention]
#     F --> G[Attention Output Linear]
#     G --> H[Residual接続 1]
#     D --> H
#     H --> I[RMSNorm]
#     I --> J[MLP: FC1]
#     J --> K[ReLU]
#     K --> L[MLP: FC2]
#     L --> M[Residual接続 2]
#     H --> M
#     M --> N[LM Head Linear]
#     N --> O[Softmax]
#     O --> P[出力確率分布]
#
#     style A fill:#e1f5ff
#     style B fill:#fff4e1
#     style C fill:#fff4e1
#     style F fill:#ffe1e1
#     style J fill:#e1ffe1
#     style K fill:#e1ffe1
#     style L fill:#e1ffe1
#     style P fill:#f0e1ff
# ```
#
# ### アーキテクチャの説明
#
# 1. **Embedding層**: 入力トークンをToken EmbeddingとPosition Embeddingに変換し、合成します
# 2. **Transformer Block**: 以下を繰り返します（n_layer = 1回）
#    - RMSNorm → Multi-Head Attention → Residual接続
#    - RMSNorm → MLP (FC1 → ReLU → FC2) → Residual接続
# 3. **LM Head**: 最終的な埋め込みベクトルを語彙サイズの次元に変換
# 4. **Softmax**: 次トークンの確率分布を計算

# %% [markdown]
# ## まとめ
#
# このNotebookでは、学習済みmicroGPTモデルの構造を確認しました：
#
# - モデルは1層のTransformerで、4つのAttentionヘッドを持つ
# - 埋め込み次元は16、コンテキスト長は16
# - 各レイヤーのパラメータ数と統計量を可視化
# - Embeddingレイヤーが最も多くのパラメータを持つ
#
# 次のNotebookでは、Attention機構の挙動を詳細に可視化します。
